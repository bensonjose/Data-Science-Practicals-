# %% [markdown]
# Create an “Academic performance” dataset of students and perform the following operations using Python.
#
# Scan all variables for missing values and inconsistencies. If there are missing values and/or
# inconsistencies, use any of the suitable techniques to deal with them. 2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable techniques to deal with them. 3. Apply data transformations on at least one of the variables. The purpose of this transformation should be one of the following reasons: to change the scale for better understanding of the variable, to convert a non-linear relation into a linear one, or to decrease the skewness and convert the distribution into a normal distribution. Reason and document your approach properly
#
# The name of dataset is Students Performance ● The features of the dataset are: Math_Score, Reading_Score, Writing_Score, Placement_Score, Club_Join_Date .
#
# ● Number of Instances: 30
#
# ● The response variable is: Placement_Offer_Count .
#
# ● Range of Values: Math_Score [60-80], Reading_Score[75-,95], ,Writing_Score [60,80], Placement_Score[75-100], Club_Join_Date [2018-2021].
#
# ● The response variable is the number of placement offers facilitated to particular students, which is largely depend on Placement_Score

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
Math_score = [random.randint(60, 80) for _ in range(400)]
missing_pct = 0.2  # 20% missing values

# Calculate the number of missing values
n_missing = int(len(Math_score) * missing_pct)

# Generate a list of indices to replace with missing values
missing_indices = random.sample(range(len(Math_score)), n_missing)

# Replace the values at the missing indices with None
for i in missing_indices:
    Math_score[i] = None

# %%
Math_score
# Out:
# [None,
#  74,
#  73,
#  78,
#  None,
#  69,
#  76,
#  67,
#  70,
#  75,
#  None,
#  72,
#  78,
#  72,
#  None,
#  60,
#  None,
#  63,
#  79,
#  74,
#  67,
#  73,
#  64,
#  77,
#  63,
#  72,
#  None,
#  None,
#  79,
#  None,
#  75,
#  None,
#  70,
#  None,
#  None,
#  67,
#  None,
#  70,
#  78,
#  70,
#  78,
#  68,
#  72,
#  71,
#  60,
#  62,
#  74,
#  69,
#  60,
#  63,
#  62,
#  None,
#  60,
#  61,
#  None,
#  72,
#  70,
#  67,
#  76,
#  69,
#  76,
#  65,
#  60,
#  76,
#  None,
#  None,
#  72,
#  60,
#  None,
#  None,
#  60,
#  70,
#  66,
#  62,
#  70,
#  None,
#  61,
#  70,
#  None,
#  None,
#  62,
#  64,
#  None,
#  79,
#  76,
#  65,
#  60,
#  68,
#  61,
#  62,
#  78,
#  80,
#  69,
#  60,
#  60,
#  74,
#  69,
#  78,
#  None,
#  None,
#  76,
#  73,
#  75,
#  66,
#  80,
#  61,
#  68,
#  77,
#  72,
#  65,
#  None,
#  78,
#  71,
#  77,
#  None,
#  None,
#  69,
#  70,
#  None,
#  None,
#  67,
#  73,
#  74,
#  69,
#  None,
#  65,
#  None,
#  75,
#  None,
#  79,
#  63,
#  None,
#  None,
#  70,
#  67,
#  63,
#  79,
#  66,
#  73,
#  73,
#  63,
#  80,
#  66,
#  63,
#  62,
#  79,
#  67,
#  79,
#  66,
#  None,
#  73,
#  None,
#  80,
#  None,
#  70,
#  71,
#  79,
#  75,
#  65,
#  None,
#  None,
#  78,
#  78,
#  67,
#  70,
#  None,
#  63,
#  None,
#  80,
#  62,
#  80,
#  63,
#  71,
#  79,
#  64,
#  60,
#  65,
#  67,
#  74,
#  69,
#  64,
#  73,
#  71,
#  71,
#  71,
#  72,
#  61,
#  78,
#  None,
#  70,
#  67,
#  73,
#  None,
#  72,
#  63,
#  68,
#  61,
#  66,
#  73,
#  75,
#  66,
#  None,
#  None,
#  74,
#  60,
#  None,
#  None,
#  60,
#  None,
#  75,
#  73,
#  None,
#  67,
#  79,
#  71,
#  66,
#  None,
#  63,
#  80,
#  60,
#  None,
#  75,
#  78,
#  77,
#  71,
#  None,
#  73,
#  78,
#  None,
#  80,
#  72,
#  None,
#  62,
#  78,
#  None,
#  66,
#  70,
#  70,
#  74,
#  62,
#  66,
#  76,
#  69,
#  67,
#  80,
#  None,
#  80,
#  69,
#  75,
#  69,
#  61,
#  70,
#  None,
#  None,
#  None,
#  60,
#  60,
#  None,
#  67,
#  76,
#  67,
#  61,
#  None,
#  69,
#  69,
#  61,
#  64,
#  73,
#  77,
#  67,
#  72,
#  74,
#  74,
#  69,
#  70,
#  70,
#  None,
#  None,
#  None,
#  68,
#  73,
#  62,
#  65,
#  67,
#  None,
#  71,
#  71,
#  62,
#  72,
#  80,
#  None,
#  None,
#  76,
#  80,
#  65,
#  70,
#  79,
#  None,
#  61,
#  71,
#  76,
#  65,
#  70,
#  65,
#  67,
#  69,
#  79,
#  65,
#  74,
#  74,
#  76,
#  61,
#  None,
#  69,
#  73,
#  63,
#  80,
#  80,
#  64,
#  66,
#  60,
#  60,
#  76,
#  65,
#  73,
#  72,
#  76,
#  77,
#  79,
#  None,
#  66,
#  66,
#  72,
#  67,
#  72,
#  None,
#  71,
#  None,
#  78,
#  79,
#  70,
#  76,
#  60,
#  68,
#  79,
#  62,
#  None,
#  69,
#  80,
#  67,
#  None,
#  None,
#  74,
#  65,
#  63,
#  73,
#  70,
#  80,
#  74,
#  77,
#  66,
#  75,
#  64,
#  71,
#  62,
#  69,
#  61,
#  64,
#  68,
#  None,
#  None,
#  73,
#  68,
#  70,
#  64,
#  73,
#  76,
#  74,
#  68,
#  None,
#  73,
#  74,
#  72,
#  65,
#  70,
#  61,
#  61,
#  None,
#  61,
#  74,
#  77,
#  64,
#  74,
#  None,
#  73,
#  64,
#  75,
#  78,
#  63,
#  75]

# %%
Reading_score = [random.randint(75, 95) for _ in range(400)]
missing_pct = 0.1  # 10% missing values

# Calculate the number of missing values
n_missing = int(len(Reading_score) * missing_pct)

# Generate a list of indices to replace with missing values
missing_indices = random.sample(range(len(Reading_score)), n_missing)

# Replace the values at the missing indices with None
for i in missing_indices:
    Reading_score[i] = None

# %%
Reading_score
# Out:
# [75,
#  None,
#  90,
#  82,
#  82,
#  None,
#  94,
#  92,
#  95,
#  93,
#  90,
#  80,
#  91,
#  75,
#  78,
#  76,
#  92,
#  79,
#  90,
#  None,
#  88,
#  76,
#  95,
#  93,
#  81,
#  86,
#  89,
#  83,
#  89,
#  77,
#  None,
#  90,
#  89,
#  75,
#  None,
#  78,
#  81,
#  None,
#  76,
#  90,
#  75,
#  93,
#  94,
#  81,
#  79,
#  93,
#  82,
#  87,
#  75,
#  79,
#  76,
#  76,
#  84,
#  79,
#  92,
#  None,
#  88,
#  87,
#  75,
#  88,
#  75,
#  92,
#  85,
#  78,
#  75,
#  84,
#  77,
#  88,
#  80,
#  None,
#  79,
#  91,
#  79,
#  87,
#  82,
#  92,
#  95,
#  None,
#  84,
#  75,
#  81,
#  94,
#  78,
#  80,
#  85,
#  91,
#  84,
#  92,
#  None,
#  83,
#  91,
#  94,
#  None,
#  84,
#  None,
#  80,
#  77,
#  76,
#  88,
#  88,
#  None,
#  79,
#  83,
#  79,
#  84,
#  87,
#  89,
#  84,
#  83,
#  91,
#  95,
#  81,
#  90,
#  93,
#  80,
#  85,
#  81,
#  92,
#  80,
#  None,
#  82,
#  80,
#  90,
#  89,
#  78,
#  82,
#  77,
#  94,
#  94,
#  79,
#  93,
#  76,
#  89,
#  77,
#  84,
#  76,
#  83,
#  81,
#  89,
#  87,
#  92,
#  90,
#  94,
#  78,
#  87,
#  91,
#  83,
#  79,
#  91,
#  93,
#  91,
#  86,
#  89,
#  91,
#  None,
#  77,
#  77,
#  82,
#  89,
#  76,
#  95,
#  None,
#  90,
#  79,
#  None,
#  75,
#  89,
#  None,
#  86,
#  84,
#  82,
#  87,
#  83,
#  87,
#  78,
#  94,
#  91,
#  79,
#  91,
#  78,
#  93,
#  79,
#  None,
#  86,
#  76,
#  75,
#  90,
#  95,
#  83,
#  None,
#  78,
#  None,
#  86,
#  92,
#  None,
#  79,
#  89,
#  77,
#  95,
#  80,
#  77,
#  93,
#  78,
#  79,
#  None,
#  78,
#  None,
#  None,
#  90,
#  88,
#  88,
#  None,
#  80,
#  81,
#  93,
#  95,
#  85,
#  87,
#  94,
#  76,
#  None,
#  85,
#  82,
#  84,
#  94,
#  82,
#  None,
#  78,
#  87,
#  85,
#  None,
#  75,
#  88,
#  86,
#  94,
#  89,
#  84,
#  79,
#  80,
#  None,
#  84,
#  78,
#  87,
#  91,
#  83,
#  75,
#  88,
#  77,
#  75,
#  79,
#  80,
#  91,
#  79,
#  87,
#  78,
#  78,
#  90,
#  83,
#  None,
#  90,
#  80,
#  84,
#  None,
#  75,
#  80,
#  86,
#  88,
#  76,
#  94,
#  90,
#  76,
#  92,
#  80,
#  80,
#  87,
#  82,
#  None,
#  80,
#  86,
#  None,
#  82,
#  76,
#  85,
#  92,
#  78,
#  92,
#  79,
#  79,
#  80,
#  76,
#  81,
#  76,
#  95,
#  81,
#  95,
#  89,
#  87,
#  84,
#  85,
#  81,
#  91,
#  91,
#  None,
#  82,
#  85,
#  79,
#  90,
#  None,
#  79,
#  86,
#  88,
#  83,
#  89,
#  89,
#  86,
#  93,
#  93,
#  80,
#  75,
#  77,
#  76,
#  83,
#  84,
#  75,
#  93,
#  82,
#  81,
#  76,
#  77,
#  95,
#  89,
#  87,
#  81,
#  78,
#  None,
#  91,
#  None,
#  86,
#  85,
#  91,
#  92,
#  92,
#  94,
#  80,
#  None,
#  94,
#  82,
#  82,
#  88,
#  85,
#  81,
#  75,
#  76,
#  77,
#  77,
#  77,
#  79,
#  80,
#  94,
#  86,
#  91,
#  86,
#  75,
#  91,
#  81,
#  92,
#  76,
#  82,
#  82,
#  92,
#  90,
#  81,
#  None,
#  92,
#  86,
#  93,
#  84,
#  83,
#  94,
#  85,
#  75,
#  84,
#  93,
#  79,
#  87,
#  94,
#  85,
#  93,
#  75,
#  85,
#  89,
#  80,
#  78,
#  78,
#  78,
#  77,
#  86,
#  89,
#  94,
#  83]

# %%
Writing_score = [random.randint(60, 80) for _ in range(400)]

# %%
Writing_score
# Out:
# [79,
#  76,
#  80,
#  73,
#  64,
#  72,
#  79,
#  80,
#  76,
#  62,
#  80,
#  62,
#  65,
#  72,
#  69,
#  60,
#  78,
#  65,
#  76,
#  60,
#  64,
#  65,
#  63,
#  76,
#  66,
#  64,
#  70,
#  74,
#  72,
#  61,
#  66,
#  68,
#  63,
#  62,
#  76,
#  61,
#  67,
#  77,
#  78,
#  77,
#  77,
#  61,
#  76,
#  71,
#  65,
#  80,
#  68,
#  72,
#  79,
#  61,
#  77,
#  67,
#  79,
#  70,
#  61,
#  78,
#  60,
#  66,
#  62,
#  68,
#  78,
#  76,
#  62,
#  73,
#  66,
#  80,
#  68,
#  77,
#  60,
#  61,
#  75,
#  76,
#  75,
#  72,
#  80,
#  67,
#  63,
#  65,
#  62,
#  73,
#  75,
#  76,
#  62,
#  77,
#  78,
#  76,
#  62,
#  76,
#  62,
#  80,
#  75,
#  62,
#  70,
#  74,
#  69,
#  70,
#  68,
#  73,
#  61,
#  79,
#  70,
#  63,
#  70,
#  79,
#  80,
#  75,
#  70,
#  69,
#  72,
#  80,
#  60,
#  72,
#  68,
#  79,
#  80,
#  68,
#  66,
#  76,
#  63,
#  62,
#  79,
#  76,
#  76,
#  73,
#  61,
#  72,
#  67,
#  68,
#  61,
#  78,
#  62,
#  61,
#  71,
#  63,
#  64,
#  60,
#  69,
#  79,
#  70,
#  60,
#  73,
#  61,
#  72,
#  63,
#  78,
#  62,
#  60,
#  80,
#  76,
#  65,
#  71,
#  69,
#  68,
#  63,
#  62,
#  73,
#  62,
#  78,
#  75,
#  77,
#  63,
#  79,
#  66,
#  76,
#  77,
#  66,
#  63,
#  76,
#  65,
#  62,
#  64,
#  74,
#  71,
#  68,
#  71,
#  63,
#  67,
#  77,
#  67,
#  74,
#  79,
#  66,
#  76,
#  62,
#  77,
#  64,
#  69,
#  62,
#  71,
#  60,
#  68,
#  78,
#  62,
#  66,
#  79,
#  62,
#  72,
#  70,
#  78,
#  76,
#  72,
#  73,
#  77,
#  73,
#  63,
#  67,
#  64,
#  64,
#  73,
#  79,
#  79,
#  80,
#  64,
#  76,
#  69,
#  74,
#  63,
#  61,
#  78,
#  67,
#  66,
#  77,
#  71,
#  63,
#  80,
#  79,
#  65,
#  69,
#  66,
#  76,
#  68,
#  69,
#  60,
#  77,
#  73,
#  74,
#  80,
#  75,
#  66,
#  70,
#  75,
#  80,
#  61,
#  79,
#  80,
#  76,
#  79,
#  69,
#  60,
#  63,
#  74,
#  64,
#  70,
#  63,
#  77,
#  73,
#  75,
#  74,
#  72,
#  76,
#  69,
#  72,
#  63,
#  79,
#  77,
#  79,
#  66,
#  78,
#  75,
#  60,
#  68,
#  78,
#  61,
#  68,
#  66,
#  79,
#  72,
#  70,
#  68,
#  73,
#  69,
#  60,
#  72,
#  62,
#  72,
#  78,
#  76,
#  61,
#  64,
#  69,
#  77,
#  63,
#  60,
#  80,
#  69,
#  79,
#  73,
#  66,
#  66,
#  72,
#  66,
#  75,
#  73,
#  63,
#  74,
#  80,
#  77,
#  63,
#  63,
#  80,
#  66,
#  77,
#  79,
#  68,
#  75,
#  61,
#  74,
#  74,
#  68,
#  72,
#  79,
#  67,
#  65,
#  73,
#  63,
#  80,
#  60,
#  77,
#  73,
#  62,
#  76,
#  78,
#  69,
#  66,
#  69,
#  64,
#  72,
#  73,
#  80,
#  60,
#  68,
#  64,
#  78,
#  67,
#  61,
#  72,
#  65,
#  79,
#  66,
#  79,
#  78,
#  74,
#  80,
#  75,
#  68,
#  66,
#  69,
#  72,
#  76,
#  72,
#  62,
#  79,
#  62,
#  62,
#  77,
#  66,
#  62,
#  75,
#  75,
#  65,
#  71,
#  60,
#  74,
#  65,
#  72,
#  71,
#  71,
#  70,
#  64,
#  75,
#  72,
#  67,
#  63,
#  64,
#  71,
#  61,
#  71,
#  72,
#  64,
#  75,
#  60,
#  73,
#  64,
#  60,
#  74,
#  80,
#  61,
#  61,
#  67,
#  67]

# %%
Placement_score = [random.randint(75, 100) for _ in range(400)]

# %%
Placement_score
# Out:
# [89,
#  93,
#  77,
#  77,
#  80,
#  94,
#  75,
#  78,
#  99,
#  90,
#  91,
#  80,
#  83,
#  77,
#  99,
#  78,
#  99,
#  100,
#  81,
#  77,
#  77,
#  80,
#  84,
#  89,
#  94,
#  97,
#  93,
#  99,
#  87,
#  81,
#  89,
#  93,
#  90,
#  76,
#  98,
#  78,
#  77,
#  78,
#  80,
#  85,
#  92,
#  78,
#  82,
#  91,
#  95,
#  89,
#  89,
#  97,
#  79,
#  100,
#  80,
#  85,
#  94,
#  94,
#  95,
#  92,
#  98,
#  89,
#  79,
#  82,
#  88,
#  75,
#  98,
#  95,
#  76,
#  86,
#  81,
#  75,
#  88,
#  80,
#  93,
#  81,
#  90,
#  85,
#  100,
#  88,
#  95,
#  91,
#  90,
#  81,
#  85,
#  93,
#  89,
#  98,
#  92,
#  98,
#  78,
#  88,
#  88,
#  78,
#  82,
#  97,
#  86,
#  91,
#  77,
#  97,
#  95,
#  83,
#  83,
#  94,
#  90,
#  83,
#  95,
#  99,
#  87,
#  77,
#  90,
#  75,
#  96,
#  76,
#  100,
#  90,
#  77,
#  98,
#  100,
#  75,
#  88,
#  96,
#  99,
#  77,
#  99,
#  83,
#  89,
#  94,
#  83,
#  96,
#  88,
#  88,
#  87,
#  100,
#  89,
#  76,
#  98,
#  82,
#  77,
#  85,
#  77,
#  87,
#  78,
#  97,
#  81,
#  81,
#  90,
#  87,
#  90,
#  86,
#  89,
#  90,
#  79,
#  93,
#  83,
#  100,
#  78,
#  75,
#  95,
#  86,
#  83,
#  95,
#  84,
#  100,
#  87,
#  84,
#  88,
#  88,
#  89,
#  95,
#  78,
#  77,
#  99,
#  95,
#  93,
#  80,
#  81,
#  91,
#  100,
#  92,
#  81,
#  97,
#  89,
#  85,
#  76,
#  90,
#  95,
#  86,
#  97,
#  75,
#  91,
#  98,
#  80,
#  97,
#  93,
#  84,
#  94,
#  81,
#  90,
#  92,
#  90,
#  90,
#  98,
#  77,
#  87,
#  80,
#  87,
#  85,
#  100,
#  91,
#  99,
#  95,
#  94,
#  94,
#  77,
#  98,
#  97,
#  89,
#  92,
#  81,
#  77,
#  96,
#  96,
#  92,
#  75,
#  92,
#  83,
#  76,
#  99,
#  85,
#  87,
#  75,
#  97,
#  98,
#  97,
#  93,
#  86,
#  81,
#  96,
#  90,
#  91,
#  88,
#  90,
#  96,
#  96,
#  78,
#  88,
#  93,
#  75,
#  89,
#  82,
#  76,
#  85,
#  82,
#  84,
#  96,
#  77,
#  100,
#  91,
#  86,
#  88,
#  93,
#  86,
#  81,
#  78,
#  78,
#  98,
#  86,
#  85,
#  99,
#  92,
#  84,
#  81,
#  84,
#  96,
#  96,
#  88,
#  78,
#  92,
#  76,
#  89,
#  95,
#  86,
#  83,
#  77,
#  95,
#  85,
#  86,
#  77,
#  77,
#  81,
#  80,
#  76,
#  80,
#  94,
#  91,
#  98,
#  93,
#  89,
#  98,
#  76,
#  88,
#  94,
#  81,
#  85,
#  75,
#  78,
#  95,
#  80,
#  98,
#  77,
#  82,
#  90,
#  94,
#  91,
#  94,
#  79,
#  82,
#  100,
#  94,
#  98,
#  93,
#  92,
#  98,
#  83,
#  76,
#  96,
#  79,
#  89,
#  94,
#  75,
#  92,
#  78,
#  76,
#  95,
#  94,
#  100,
#  85,
#  85,
#  93,
#  81,
#  96,
#  94,
#  85,
#  80,
#  94,
#  92,
#  81,
#  89,
#  95,
#  97,
#  78,
#  84,
#  82,
#  75,
#  79,
#  91,
#  81,
#  84,
#  77,
#  92,
#  100,
#  83,
#  89,
#  75,
#  86,
#  78,
#  77,
#  81,
#  82,
#  83,
#  95,
#  92,
#  81,
#  75,
#  92,
#  88,
#  78,
#  78,
#  88,
#  96,
#  89,
#  79,
#  87,
#  80,
#  77,
#  90,
#  97,
#  100,
#  95,
#  78,
#  100,
#  81,
#  89,
#  83,
#  76,
#  88,
#  83,
#  95,
#  75,
#  93,
#  75,
#  83,
#  80]

# %%
Club_list = ['2018', '2019','2020', '2021']
Club_Join_Date= [random.choice(Club_list) for _ in range(400)]

# %%
Club_Join_Date
# Out:
# ['2018',
#  '2020',
#  '2021',
#  '2018',
#  '2020',
#  '2018',
#  '2021',
#  '2019',
#  '2018',
#  '2019',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2021',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2018',
#  '2018',
#  '2018',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2018',
#  '2020',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2018',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2019',
#  '2018',
#  '2020',
#  '2018',
#  '2018',
#  '2019',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2021',
#  '2019',
#  '2019',
#  '2021',
#  '2021',
#  '2019',
#  '2019',
#  '2018',
#  '2021',
#  '2019',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2019',
#  '2020',
#  '2021',
#  '2019',
#  '2019',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2019',
#  '2021',
#  '2018',
#  '2021',
#  '2018',
#  '2018',
#  '2019',
#  '2019',
#  '2021',
#  '2019',
#  '2018',
#  '2019',
#  '2019',
#  '2020',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2018',
#  '2018',
#  '2020',
#  '2018',
#  '2021',
#  '2019',
#  '2021',
#  '2018',
#  '2020',
#  '2019',
#  '2019',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2019',
#  '2019',
#  '2019',
#  '2020',
#  '2020',
#  '2019',
#  '2020',
#  '2021',
#  '2019',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2018',
#  '2018',
#  '2019',
#  '2018',
#  '2021',
#  '2020',
#  '2018',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2019',
#  '2020',
#  '2018',
#  '2020',
#  '2019',
#  '2019',
#  '2020',
#  '2021',
#  '2018',
#  '2020',
#  '2021',
#  '2018',
#  '2019',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2019',
#  '2021',
#  '2021',
#  '2018',
#  '2020',
#  '2020',
#  '2019',
#  '2021',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2019',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2018',
#  '2021',
#  '2018',
#  '2021',
#  '2018',
#  '2019',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2019',
#  '2021',
#  '2020',
#  '2018',
#  '2020',
#  '2021',
#  '2021',
#  '2018',
#  '2021',
#  '2021',
#  '2019',
#  '2018',
#  '2019',
#  '2021',
#  '2018',
#  '2019',
#  '2019',
#  '2019',
#  '2021',
#  '2019',
#  '2019',
#  '2020',
#  '2019',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2018',
#  '2020',
#  '2019',
#  '2020',
#  '2019',
#  '2021',
#  '2018',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2018',
#  '2018',
#  '2019',
#  '2021',
#  '2018',
#  '2020',
#  '2018',
#  '2019',
#  '2021',
#  '2018',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2019',
#  '2020',
#  '2020',
#  '2018',
#  '2019',
#  '2021',
#  '2020',
#  '2020',
#  '2021',
#  '2018',
#  '2019',
#  '2018',
#  '2020',
#  '2019',
#  '2020',
#  '2018',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2021',
#  '2018',
#  '2018',
#  '2020',
#  '2019',
#  '2019',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2018',
#  '2019',
#  '2019',
#  '2019',
#  '2020',
#  '2018',
#  '2018',
#  '2020',
#  '2020',
#  '2018',
#  '2020',
#  '2019',
#  '2020',
#  '2021',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2020',
#  '2018',
#  '2020',
#  '2018',
#  '2019',
#  '2019',
#  '2021',
#  '2019',
#  '2021',
#  '2021',
#  '2019',
#  '2018',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2021',
#  '2018',
#  '2018',
#  '2020',
#  '2018',
#  '2019',
#  '2019',
#  '2020',
#  '2021',
#  '2020',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2019',
#  '2018',
#  '2020',
#  '2018',
#  '2021',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2018',
#  '2020',
#  '2019',
#  '2021',
#  '2018',
#  '2020',
#  '2019',
#  '2020',
#  '2021',
#  '2018',
#  '2018',
#  '2020',
#  '2019',
#  '2018',
#  '2020',
#  '2019',
#  '2021',
#  '2018',
#  '2021',
#  '2021',
#  '2020',
#  '2021',
#  '2018',
#  '2018',
#  '2021',
#  '2019',
#  '2018',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2021',
#  '2018',
#  '2020',
#  '2019',
#  '2019',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019']

# %%
df = {}

df["Math_score"] = Math_score
df['Reading_score'] = Reading_score
df["Writing_score"] = Writing_score
df["Placement_score"] =Placement_score
df["Club_Join_Date"] = Club_Join_Date

# %%
df
# Out:
# {'Math_score': [None,
#   74,
#   73,
#   78,
#   None,
#   69,
#   76,
#   67,
#   70,
#   75,
#   None,
#   72,
#   78,
#   72,
#   None,
#   60,
#   None,
#   63,
#   79,
#   74,
#   67,
#   73,
#   64,
#   77,
#   63,
#   72,
#   None,
#   None,
#   79,
#   None,
#   75,
#   None,
#   70,
#   None,
#   None,
#   67,
#   None,
#   70,
#   78,
#   70,
#   78,
#   68,
#   72,
#   71,
#   60,
#   62,
#   74,
#   69,
#   60,
#   63,
#   62,
#   None,
#   60,
#   61,
#   None,
#   72,
#   70,
#   67,
#   76,
#   69,
#   76,
#   65,
#   60,
#   76,
#   None,
#   None,
#   72,
#   60,
#   None,
#   None,
#   60,
#   70,
#   66,
#   62,
#   70,
#   None,
#   61,
#   70,
#   None,
#   None,
#   62,
#   64,
#   None,
#   79,
#   76,
#   65,
#   60,
#   68,
#   61,
#   62,
#   78,
#   80,
#   69,
#   60,
#   60,
#   74,
#   69,
#   78,
#   None,
#   None,
#   76,
#   73,
#   75,
#   66,
#   80,
#   61,
#   68,
#   77,
#   72,
#   65,
#   None,
#   78,
#   71,
#   77,
#   None,
#   None,
#   69,
#   70,
#   None,
#   None,
#   67,
#   73,
#   74,
#   69,
#   None,
#   65,
#   None,
#   75,
#   None,
#   79,
#   63,
#   None,
#   None,
#   70,
#   67,
#   63,
#   79,
#   66,
#   73,
#   73,
#   63,
#   80,
#   66,
#   63,
#   62,
#   79,
#   67,
#   79,
#   66,
#   None,
#   73,
#   None,
#   80,
#   None,
#   70,
#   71,
#   79,
#   75,
#   65,
#   None,
#   None,
#   78,
#   78,
#   67,
#   70,
#   None,
#   63,
#   None,
#   80,
#   62,
#   80,
#   63,
#   71,
#   79,
#   64,
#   60,
#   65,
#   67,
#   74,
#   69,
#   64,
#   73,
#   71,
#   71,
#   71,
#   72,
#   61,
#   78,
#   None,
#   70,
#   67,
#   73,
#   None,
#   72,
#   63,
#   68,
#   61,
#   66,
#   73,
#   75,
#   66,
#   None,
#   None,
#   74,
#   60,
#   None,
#   None,
#   60,
#   None,
#   75,
#   73,
#   None,
#   67,
#   79,
#   71,
#   66,
#   None,
#   63,
#   80,
#   60,
#   None,
#   75,
#   78,
#   77,
#   71,
#   None,
#   73,
#   78,
#   None,
#   80,
#   72,
#   None,
#   62,
#   78,
#   None,
#   66,
#   70,
#   70,
#   74,
#   62,
#   66,
#   76,
#   69,
#   67,
#   80,
#   None,
#   80,
#   69,
#   75,
#   69,
#   61,
#   70,
#   None,
#   None,
#   None,
#   60,
#   60,
#   None,
#   67,
#   76,
#   67,
#   61,
#   None,
#   69,
#   69,
#   61,
#   64,
#   73,
#   77,
#   67,
#   72,
#   74,
#   74,
#   69,
#   70,
#   70,
#   None,
#   None,
#   None,
#   68,
#   73,
#   62,
#   65,
#   67,
#   None,
#   71,
#   71,
#   62,
#   72,
#   80,
#   None,
#   None,
#   76,
#   80,
#   65,
#   70,
#   79,
#   None,
#   61,
#   71,
#   76,
#   65,
#   70,
#   65,
#   67,
#   69,
#   79,
#   65,
#   74,
#   74,
#   76,
#   61,
#   None,
#   69,
#   73,
#   63,
#   80,
#   80,
#   64,
#   66,
#   60,
#   60,
#   76,
#   65,
#   73,
#   72,
#   76,
#   77,
#   79,
#   None,
#   66,
#   66,
#   72,
#   67,
#   72,
#   None,
#   71,
#   None,
#   78,
#   79,
#   70,
#   76,
#   60,
#   68,
#   79,
#   62,
#   None,
#   69,
#   80,
#   67,
#   None,
#   None,
#   74,
#   65,
#   63,
#   73,
#   70,
#   80,
#   74,
#   77,
#   66,
#   75,
#   64,
#   71,
#   62,
#   69,
#   61,
#   64,
#   68,
#   None,
#   None,
#   73,
#   68,
#   70,
#   64,
#   73,
#   76,
#   74,
#   68,
#   None,
#   73,
#   74,
#   72,
#   65,
#   70,
#   61,
#   61,
#   None,
#   61,
#   74,
#   77,
#   64,
#   74,
#   None,
#   73,
#   64,
#   75,
#   78,
#   63,
#   75],
#  'Reading_score': [75,
#   None,
#   90,
#   82,
#   82,
#   None,
#   94,
#   92,
#   95,
#   93,
#   90,
#   80,
#   91,
#   75,
#   78,
#   76,
#   92,
#   79,
#   90,
#   None,
#   88,
#   76,
#   95,
#   93,
#   81,
#   86,
#   89,
#   83,
#   89,
#   77,
#   None,
#   90,
#   89,
#   75,
#   None,
#   78,
#   81,
#   None,
#   76,
#   90,
#   75,
#   93,
#   94,
#   81,
#   79,
#   93,
#   82,
#   87,
#   75,
#   79,
#   76,
#   76,
#   84,
#   79,
#   92,
#   None,
#   88,
#   87,
#   75,
#   88,
#   75,
#   92,
#   85,
#   78,
#   75,
#   84,
#   77,
#   88,
#   80,
#   None,
#   79,
#   91,
#   79,
#   87,
#   82,
#   92,
#   95,
#   None,
#   84,
#   75,
#   81,
#   94,
#   78,
#   80,
#   85,
#   91,
#   84,
#   92,
#   None,
#   83,
#   91,
#   94,
#   None,
#   84,
#   None,
#   80,
#   77,
#   76,
#   88,
#   88,
#   None,
#   79,
#   83,
#   79,
#   84,
#   87,
#   89,
#   84,
#   83,
#   91,
#   95,
#   81,
#   90,
#   93,
#   80,
#   85,
#   81,
#   92,
#   80,
#   None,
#   82,
#   80,
#   90,
#   89,
#   78,
#   82,
#   77,
#   94,
#   94,
#   79,
#   93,
#   76,
#   89,
#   77,
#   84,
#   76,
#   83,
#   81,
#   89,
#   87,
#   92,
#   90,
#   94,
#   78,
#   87,
#   91,
#   83,
#   79,
#   91,
#   93,
#   91,
#   86,
#   89,
#   91,
#   None,
#   77,
#   77,
#   82,
#   89,
#   76,
#   95,
#   None,
#   90,
#   79,
#   None,
#   75,
#   89,
#   None,
#   86,
#   84,
#   82,
#   87,
#   83,
#   87,
#   78,
#   94,
#   91,
#   79,
#   91,
#   78,
#   93,
#   79,
#   None,
#   86,
#   76,
#   75,
#   90,
#   95,
#   83,
#   None,
#   78,
#   None,
#   86,
#   92,
#   None,
#   79,
#   89,
#   77,
#   95,
#   80,
#   77,
#   93,
#   78,
#   79,
#   None,
#   78,
#   None,
#   None,
#   90,
#   88,
#   88,
#   None,
#   80,
#   81,
#   93,
#   95,
#   85,
#   87,
#   94,
#   76,
#   None,
#   85,
#   82,
#   84,
#   94,
#   82,
#   None,
#   78,
#   87,
#   85,
#   None,
#   75,
#   88,
#   86,
#   94,
#   89,
#   84,
#   79,
#   80,
#   None,
#   84,
#   78,
#   87,
#   91,
#   83,
#   75,
#   88,
#   77,
#   75,
#   79,
#   80,
#   91,
#   79,
#   87,
#   78,
#   78,
#   90,
#   83,
#   None,
#   90,
#   80,
#   84,
#   None,
#   75,
#   80,
#   86,
#   88,
#   76,
#   94,
#   90,
#   76,
#   92,
#   80,
#   80,
#   87,
#   82,
#   None,
#   80,
#   86,
#   None,
#   82,
#   76,
#   85,
#   92,
#   78,
#   92,
#   79,
#   79,
#   80,
#   76,
#   81,
#   76,
#   95,
#   81,
#   95,
#   89,
#   87,
#   84,
#   85,
#   81,
#   91,
#   91,
#   None,
#   82,
#   85,
#   79,
#   90,
#   None,
#   79,
#   86,
#   88,
#   83,
#   89,
#   89,
#   86,
#   93,
#   93,
#   80,
#   75,
#   77,
#   76,
#   83,
#   84,
#   75,
#   93,
#   82,
#   81,
#   76,
#   77,
#   95,
#   89,
#   87,
#   81,
#   78,
#   None,
#   91,
#   None,
#   86,
#   85,
#   91,
#   92,
#   92,
#   94,
#   80,
#   None,
#   94,
#   82,
#   82,
#   88,
#   85,
#   81,
#   75,
#   76,
#   77,
#   77,
#   77,
#   79,
#   80,
#   94,
#   86,
#   91,
#   86,
#   75,
#   91,
#   81,
#   92,
#   76,
#   82,
#   82,
#   92,
#   90,
#   81,
#   None,
#   92,
#   86,
#   93,
#   84,
#   83,
#   94,
#   85,
#   75,
#   84,
#   93,
#   79,
#   87,
#   94,
#   85,
#   93,
#   75,
#   85,
#   89,
#   80,
#   78,
#   78,
#   78,
#   77,
#   86,
#   89,
#   94,
#   83],
#  'Writing_score': [79,
#   76,
#   80,
#   73,
#   64,
#   72,
#   79,
#   80,
#   76,
#   62,
#   80,
#   62,
#   65,
#   72,
#   69,
#   60,
#   78,
#   65,
#   76,
#   60,
#   64,
#   65,
#   63,
#   76,
#   66,
#   64,
#   70,
#   74,
#   72,
#   61,
#   66,
#   68,
#   63,
#   62,
#   76,
#   61,
#   67,
#   77,
#   78,
#   77,
#   77,
#   61,
#   76,
#   71,
#   65,
#   80,
#   68,
#   72,
#   79,
#   61,
#   77,
#   67,
#   79,
#   70,
#   61,
#   78,
#   60,
#   66,
#   62,
#   68,
#   78,
#   76,
#   62,
#   73,
#   66,
#   80,
#   68,
#   77,
#   60,
#   61,
#   75,
#   76,
#   75,
#   72,
#   80,
#   67,
#   63,
#   65,
#   62,
#   73,
#   75,
#   76,
#   62,
#   77,
#   78,
#   76,
#   62,
#   76,
#   62,
#   80,
#   75,
#   62,
#   70,
#   74,
#   69,
#   70,
#   68,
#   73,
#   61,
#   79,
#   70,
#   63,
#   70,
#   79,
#   80,
#   75,
#   70,
#   69,
#   72,
#   80,
#   60,
#   72,
#   68,
#   79,
#   80,
#   68,
#   66,
#   76,
#   63,
#   62,
#   79,
#   76,
#   76,
#   73,
#   61,
#   72,
#   67,
#   68,
#   61,
#   78,
#   62,
#   61,
#   71,
#   63,
#   64,
#   60,
#   69,
#   79,
#   70,
#   60,
#   73,
#   61,
#   72,
#   63,
#   78,
#   62,
#   60,
#   80,
#   76,
#   65,
#   71,
#   69,
#   68,
#   63,
#   62,
#   73,
#   62,
#   78,
#   75,
#   77,
#   63,
#   79,
#   66,
#   76,
#   77,
#   66,
#   63,
#   76,
#   65,
#   62,
#   64,
#   74,
#   71,
#   68,
#   71,
#   63,
#   67,
#   77,
#   67,
#   74,
#   79,
#   66,
#   76,
#   62,
#   77,
#   64,
#   69,
#   62,
#   71,
#   60,
#   68,
#   78,
#   62,
#   66,
#   79,
#   62,
#   72,
#   70,
#   78,
#   76,
#   72,
#   73,
#   77,
#   73,
#   63,
#   67,
#   64,
#   64,
#   73,
#   79,
#   79,
#   80,
#   64,
#   76,
#   69,
#   74,
#   63,
#   61,
#   78,
#   67,
#   66,
#   77,
#   71,
#   63,
#   80,
#   79,
#   65,
#   69,
#   66,
#   76,
#   68,
#   69,
#   60,
#   77,
#   73,
#   74,
#   80,
#   75,
#   66,
#   70,
#   75,
#   80,
#   61,
#   79,
#   80,
#   76,
#   79,
#   69,
#   60,
#   63,
#   74,
#   64,
#   70,
#   63,
#   77,
#   73,
#   75,
#   74,
#   72,
#   76,
#   69,
#   72,
#   63,
#   79,
#   77,
#   79,
#   66,
#   78,
#   75,
#   60,
#   68,
#   78,
#   61,
#   68,
#   66,
#   79,
#   72,
#   70,
#   68,
#   73,
#   69,
#   60,
#   72,
#   62,
#   72,
#   78,
#   76,
#   61,
#   64,
#   69,
#   77,
#   63,
#   60,
#   80,
#   69,
#   79,
#   73,
#   66,
#   66,
#   72,
#   66,
#   75,
#   73,
#   63,
#   74,
#   80,
#   77,
#   63,
#   63,
#   80,
#   66,
#   77,
#   79,
#   68,
#   75,
#   61,
#   74,
#   74,
#   68,
#   72,
#   79,
#   67,
#   65,
#   73,
#   63,
#   80,
#   60,
#   77,
#   73,
#   62,
#   76,
#   78,
#   69,
#   66,
#   69,
#   64,
#   72,
#   73,
#   80,
#   60,
#   68,
#   64,
#   78,
#   67,
#   61,
#   72,
#   65,
#   79,
#   66,
#   79,
#   78,
#   74,
#   80,
#   75,
#   68,
#   66,
#   69,
#   72,
#   76,
#   72,
#   62,
#   79,
#   62,
#   62,
#   77,
#   66,
#   62,
#   75,
#   75,
#   65,
#   71,
#   60,
#   74,
#   65,
#   72,
#   71,
#   71,
#   70,
#   64,
#   75,
#   72,
#   67,
#   63,
#   64,
#   71,
#   61,
#   71,
#   72,
#   64,
#   75,
#   60,
#   73,
#   64,
#   60,
#   74,
#   80,
#   61,
#   61,
#   67,
#   67],
#  'Placement_score': [89,
#   93,
#   77,
#   77,
#   80,
#   94,
#   75,
#   78,
#   99,
#   90,
#   91,
#   80,
#   83,
#   77,
#   99,
#   78,
#   99,
#   100,
#   81,
#   77,
#   77,
#   80,
#   84,
#   89,
#   94,
#   97,
#   93,
#   99,
#   87,
#   81,
#   89,
#   93,
#   90,
#   76,
#   98,
#   78,
#   77,
#   78,
#   80,
#   85,
#   92,
#   78,
#   82,
#   91,
#   95,
#   89,
#   89,
#   97,
#   79,
#   100,
#   80,
#   85,
#   94,
#   94,
#   95,
#   92,
#   98,
#   89,
#   79,
#   82,
#   88,
#   75,
#   98,
#   95,
#   76,
#   86,
#   81,
#   75,
#   88,
#   80,
#   93,
#   81,
#   90,
#   85,
#   100,
#   88,
#   95,
#   91,
#   90,
#   81,
#   85,
#   93,
#   89,
#   98,
#   92,
#   98,
#   78,
#   88,
#   88,
#   78,
#   82,
#   97,
#   86,
#   91,
#   77,
#   97,
#   95,
#   83,
#   83,
#   94,
#   90,
#   83,
#   95,
#   99,
#   87,
#   77,
#   90,
#   75,
#   96,
#   76,
#   100,
#   90,
#   77,
#   98,
#   100,
#   75,
#   88,
#   96,
#   99,
#   77,
#   99,
#   83,
#   89,
#   94,
#   83,
#   96,
#   88,
#   88,
#   87,
#   100,
#   89,
#   76,
#   98,
#   82,
#   77,
#   85,
#   77,
#   87,
#   78,
#   97,
#   81,
#   81,
#   90,
#   87,
#   90,
#   86,
#   89,
#   90,
#   79,
#   93,
#   83,
#   100,
#   78,
#   75,
#   95,
#   86,
#   83,
#   95,
#   84,
#   100,
#   87,
#   84,
#   88,
#   88,
#   89,
#   95,
#   78,
#   77,
#   99,
#   95,
#   93,
#   80,
#   81,
#   91,
#   100,
#   92,
#   81,
#   97,
#   89,
#   85,
#   76,
#   90,
#   95,
#   86,
#   97,
#   75,
#   91,
#   98,
#   80,
#   97,
#   93,
#   84,
#   94,
#   81,
#   90,
#   92,
#   90,
#   90,
#   98,
#   77,
#   87,
#   80,
#   87,
#   85,
#   100,
#   91,
#   99,
#   95,
#   94,
#   94,
#   77,
#   98,
#   97,
#   89,
#   92,
#   81,
#   77,
#   96,
#   96,
#   92,
#   75,
#   92,
#   83,
#   76,
#   99,
#   85,
#   87,
#   75,
#   97,
#   98,
#   97,
#   93,
#   86,
#   81,
#   96,
#   90,
#   91,
#   88,
#   90,
#   96,
#   96,
#   78,
#   88,
#   93,
#   75,
#   89,
#   82,
#   76,
#   85,
#   82,
#   84,
#   96,
#   77,
#   100,
#   91,
#   86,
#   88,
#   93,
#   86,
#   81,
#   78,
#   78,
#   98,
#   86,
#   85,
#   99,
#   92,
#   84,
#   81,
#   84,
#   96,
#   96,
#   88,
#   78,
#   92,
#   76,
#   89,
#   95,
#   86,
#   83,
#   77,
#   95,
#   85,
#   86,
#   77,
#   77,
#   81,
#   80,
#   76,
#   80,
#   94,
#   91,
#   98,
#   93,
#   89,
#   98,
#   76,
#   88,
#   94,
#   81,
#   85,
#   75,
#   78,
#   95,
#   80,
#   98,
#   77,
#   82,
#   90,
#   94,
#   91,
#   94,
#   79,
#   82,
#   100,
#   94,
#   98,
#   93,
#   92,
#   98,
#   83,
#   76,
#   96,
#   79,
#   89,
#   94,
#   75,
#   92,
#   78,
#   76,
#   95,
#   94,
#   100,
#   85,
#   85,
#   93,
#   81,
#   96,
#   94,
#   85,
#   80,
#   94,
#   92,
#   81,
#   89,
#   95,
#   97,
#   78,
#   84,
#   82,
#   75,
#   79,
#   91,
#   81,
#   84,
#   77,
#   92,
#   100,
#   83,
#   89,
#   75,
#   86,
#   78,
#   77,
#   81,
#   82,
#   83,
#   95,
#   92,
#   81,
#   75,
#   92,
#   88,
#   78,
#   78,
#   88,
#   96,
#   89,
#   79,
#   87,
#   80,
#   77,
#   90,
#   97,
#   100,
#   95,
#   78,
#   100,
#   81,
#   89,
#   83,
#   76,
#   88,
#   83,
#   95,
#   75,
#   93,
#   75,
#   83,
#   80],
#  'Club_Join_Date': ['2018',
#   '2020',
#   '2021',
#   '2018',
#   '2020',
#   '2018',
#   '2021',
#   '2019',
#   '2018',
#   '2019',
#   '2021',
#   '2021',
#   '2020',
#   '2020',
#   '2021',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2018',
#   '2018',
#   '2018',
#   '2020',
#   '2020',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2018',
#   '2018',
#   '2020',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2018',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2019',
#   '2018',
#   '2020',
#   '2018',
#   '2018',
#   '2019',
#   '2020',
#   '2018',
#   '2018',
#   '2018',
#   '2021',
#   '2019',
#   '2019',
#   '2021',
#   '2021',
#   '2019',
#   '2019',
#   '2018',
#   '2021',
#   '2019',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2019',
#   '2020',
#   '2021',
#   '2019',
#   '2019',
#   '2020',
#   '2020',
#   '2021',
#   '2021',
#   '2021',
#   '2019',
#   '2021',
#   '2018',
#   '2021',
#   '2018',
#   '2018',
#   '2019',
#   '2019',
#   '2021',
#   '2019',
#   '2018',
#   '2019',
#   '2019',
#   '2020',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2018',
#   '2018',
#   '2020',
#   '2018',
#   '2021',
#   '2019',
#   '2021',
#   '2018',
#   '2020',
#   '2019',
#   '2019',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2019',
#   '2019',
#   '2019',
#   '2020',
#   '2020',
#   '2019',
#   '2020',
#   '2021',
#   '2019',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2018',
#   '2018',
#   '2019',
#   '2018',
#   '2021',
#   '2020',
#   '2018',
#   '2020',
#   '2021',
#   '2021',
#   '2021',
#   '2021',
#   '2019',
#   '2020',
#   '2018',
#   '2020',
#   '2019',
#   '2019',
#   '2020',
#   '2021',
#   '2018',
#   '2020',
#   '2021',
#   '2018',
#   '2019',
#   '2021',
#   '2021',
#   '2021',
#   '2021',
#   '2019',
#   '2021',
#   '2021',
#   '2018',
#   '2020',
#   '2020',
#   '2019',
#   '2021',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2019',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2018',
#   '2021',
#   '2018',
#   '2021',
#   '2018',
#   '2019',
#   '2019',
#   '2021',
#   '2020',
#   '2021',
#   '2019',
#   '2021',
#   '2020',
#   '2018',
#   '2020',
#   '2021',
#   '2021',
#   '2018',
#   '2021',
#   '2021',
#   '2019',
#   '2018',
#   '2019',
#   '2021',
#   '2018',
#   '2019',
#   '2019',
#   '2019',
#   '2021',
#   '2019',
#   '2019',
#   '2020',
#   '2019',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2018',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2020',
#   '2019',
#   '2019',
#   '2020',
#   '2020',
#   '2021',
#   '2021',
#   '2021',
#   '2020',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2021',
#   '2018',
#   '2020',
#   '2019',
#   '2020',
#   '2019',
#   '2021',
#   '2018',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2018',
#   '2018',
#   '2019',
#   '2021',
#   '2018',
#   '2020',
#   '2018',
#   '2019',
#   '2021',
#   '2018',
#   '2020',
#   '2021',
#   '2021',
#   '2021',
#   '2019',
#   '2020',
#   '2020',
#   '2018',
#   '2019',
#   '2021',
#   '2020',
#   '2020',
#   '2021',
#   '2018',
#   '2019',
#   '2018',
#   '2020',
#   '2019',
#   '2020',
#   '2018',
#   '2019',
#   '2019',
#   '2019',
#   '2018',
#   '2021',
#   '2018',
#   '2018',
#   '2020',
#   '2019',
#   '2019',
#   '2020',
#   '2018',
#   '2018',
#   '2018',
#   '2019',
#   '2018',
#   '2019',
#   '2019',
#   '2019',
#   '2020',
#   '2018',
#   '2018',
#   '2020',
#   '2020',
#   '2018',
#   '2020',
#   '2019',
#   '2020',
#   '2021',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2020',
#   '2018',
#   '2020',
#   '2018',
#   '2019',
#   '2019',
#   '2021',
#   '2019',
#   '2021',
#   '2021',
#   '2019',
#   '2018',
#   '2021',
#   '2020',
#   '2019',
#   '2018',
#   '2021',
#   '2018',
#   '2018',
#   '2020',
#   '2018',
#   '2019',
#   '2019',
#   '2020',
#   '2021',
#   '2020',
#   '2020',
#   '2019',
#   '2021',
#   '2020',
#   '2020',
#   '2020',
#   '2020',
#   '2021',
#   '2019',
#   '2018',
#   '2020',
#   '2018',
#   '2021',
#   '2020',
#   '2020',
#   '2021',
#   '2021',
#   '2018',
#   '2020',
#   '2019',
#   '2021',
#   '2018',
#   '2020',
#   '2019',
#   '2020',
#   '2021',
#   '2018',
#   '2018',
#   '2020',
#   '2019',
#   '2018',
#   '2020',
#   '2019',
#   '2021',
#   '2018',
#   '2021',
#   '2021',
#   '2020',
#   '2021',
#   '2018',
#   '2018',
#   '2021',
#   '2019',
#   '2018',
#   '2020',
#   '2018',
#   '2018',
#   '2018',
#   '2018',
#   '2021',
#   '2018',
#   '2020',
#   '2019',
#   '2019',
#   '2021',
#   '2020',
#   '2019',
#   '2020',
#   '2020',
#   '2020',
#   '2020',
#   '2019']}

# %%
dataFrame = pd.DataFrame(df)

# %%
dataFrame.to_csv("Student_performance.csv")

# %% [markdown]
# Data Preprocessing

# %%
dataFrame.shape
# Out:
# (400, 5)

# %%
dataFrame.head()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 0         NaN           75.0             79               89           2018
# 1        74.0            NaN             76               93           2020
# 2        73.0           90.0             80               77           2021
# 3        78.0           82.0             73               77           2018
# 4         NaN           82.0             64               80           2020

# %%
dataFrame.tail()
# Out:
#      Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 395        64.0           77.0             80               75           2020
# 396        75.0           86.0             61               93           2020
# 397        78.0           89.0             61               75           2020
# 398        63.0           94.0             67               83           2020
# 399        75.0           83.0             67               80           2019

# %%
dataFrame.columns
# Out:
# Index(['Math_score', 'Reading_score', 'Writing_score', 'Placement_score',
#        'Club_Join_Date'],
#       dtype='object')

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_score       320 non-null    float64
#  1   Reading_score    360 non-null    float64
#  2   Writing_score    400 non-null    int64
#  3   Placement_score  400 non-null    int64
#  4   Club_Join_Date   400 non-null    object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 15.8+ KB

# %%
dataFrame.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score
# count  320.000000     360.000000     400.000000       400.000000
# mean    69.968750      84.447222      70.182500        87.372500
# std      5.975312       6.127021       6.354932         7.598558
# min     60.000000      75.000000      60.000000        75.000000
# 25%     65.000000      79.000000      64.000000        81.000000
# 50%     70.000000      84.000000      70.000000        88.000000
# 75%     75.000000      90.000000      76.000000        94.000000
# max     80.000000      95.000000      80.000000       100.000000

# %%
dataFrame.dtypes
# Out:
# Math_score         float64
# Reading_score      float64
# Writing_score        int64
# Placement_score      int64
# Club_Join_Date      object
# dtype: object

# %%
dataFrame.iloc[:,0:4].head(5)
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score
# 0         NaN           75.0             79               89
# 1        74.0            NaN             76               93
# 2        73.0           90.0             80               77
# 3        78.0           82.0             73               77
# 4         NaN           82.0             64               80

# %%
dataFrame.loc[:,["Placement_score","Club_Join_Date"]].head(5)
# Out:
#    Placement_score Club_Join_Date
# 0               89           2018
# 1               93           2020
# 2               77           2021
# 3               77           2018
# 4               80           2020

# %%
dataFrame['Club_Join_Date'].value_counts()
# Out:
# 2019    106
# 2020    104
# 2021     97
# 2018     93
# Name: Club_Join_Date, dtype: int64

# %%
dataFrame.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score
# count  320.000000     360.000000     400.000000       400.000000
# mean    69.968750      84.447222      70.182500        87.372500
# std      5.975312       6.127021       6.354932         7.598558
# min     60.000000      75.000000      60.000000        75.000000
# 25%     65.000000      79.000000      64.000000        81.000000
# 50%     70.000000      84.000000      70.000000        88.000000
# 75%     75.000000      90.000000      76.000000        94.000000
# max     80.000000      95.000000      80.000000       100.000000

# %%
dataFrame.duplicated().sum()
# Out:
# 0

# %%
dataFrame.sum()
# Out:
# Math_score                                                   22390.0
# Reading_score                                                30401.0
# Writing_score                                                  28073
# Placement_score                                                34949
# Club_Join_Date     2018202020212018202020182021201920182019202120...
# dtype: object

# %%
dataFrame.nunique()
# Out:
# Math_score         21
# Reading_score      21
# Writing_score      21
# Placement_score    26
# Club_Join_Date      4
# dtype: int64

# %%
dataFrame.isnull().sum()
# Out:
# Math_score         80
# Reading_score      40
# Writing_score       0
# Placement_score     0
# Club_Join_Date      0
# dtype: int64

# %%
dataFrame['Math_score'].fillna(dataFrame['Math_score'].mean(), inplace=True)
dataFrame['Reading_score'].fillna(dataFrame['Reading_score'].mean(), inplace=True)

# %%
pd.get_dummies(dataFrame,columns=['Club_Join_Date']).head()  # label Encoding
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score  \
# 0    69.96875      75.000000             79               89
# 1    74.00000      84.447222             76               93
# 2    73.00000      90.000000             80               77
# 3    78.00000      82.000000             73               77
# 4    69.96875      82.000000             64               80
#
#    Club_Join_Date_2018  Club_Join_Date_2019  Club_Join_Date_2020  \
# 0                    1                    0                    0
# 1                    0                    0                    1
# 2                    0                    0                    0
# 3                    1                    0                    0
# 4                    0                    0                    1
#
#    Club_Join_Date_2021
# 0                    0
# 1                    0
# 2                    1
# 3                    0
# 4                    0

# %%
# Generating outliers
for i in [random.randint(0, 400) for _ in range(8)]:
    
    dataFrame['Math_score'][i] = random.randint(-10, 20)

# %%
dataFrame['Math_score'].describe()
# Out:
# count    400.000000
# mean      68.641328
# std       10.334346
# min       -8.000000
# 25%       66.000000
# 50%       69.968750
# 75%       73.000000
# max       80.000000
# Name: Math_score, dtype: float64

# %%
#detecting outliers
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataFrame['Math_score'])

plt.subplot(2,2,2)
sns.boxplot(dataFrame['Math_score'])
# Out:
# <Axes: >

# %%
percentile25 = dataFrame['Math_score'].quantile(0.25)
percentile75 = dataFrame['Math_score'].quantile(0.75)

# %%
percentile25
# Out:
# 66.0

# %%
percentile75
# Out:
# 73.0

# %%
iqr = percentile75 - percentile25
iqr
# Out:
# 7.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 83.5
# Lower limit 55.5

# %% [markdown]
# finding outliers

# %%
dataFrame[dataFrame['Math_score'] > upper_limit]
# Out:
# Empty DataFrame
# Columns: [Math_score, Reading_score, Writing_score, Placement_score, Club_Join_Date]
# Index: []

# %%
dataFrame[dataFrame['Math_score'] < lower_limit]
# Out:
#      Math_score  Reading_score  Writing_score  Placement_score Club_Join_Date
# 40         16.0           75.0             77               92           2020
# 41         -8.0           93.0             61               78           2018
# 70          7.0           79.0             75               93           2019
# 153         8.0           91.0             63               75           2019
# 193        16.0           92.0             66               81           2021
# 213        19.0           81.0             76               89           2021
# 289        -2.0           76.0             69               80           2018
# 357         0.0           80.0             72              100           2019

# %% [markdown]
# Trimming

# %%
new_dataFrame = dataFrame[dataFrame['Math_score'] > lower_limit]
new_dataFrame.shape
# Out:
# (392, 5)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataFrame['Math_score'])

plt.subplot(2,2,2)
sns.boxplot(dataFrame['Math_score'])

plt.subplot(2,2,3)
sns.distplot(new_dataFrame['Math_score'])

plt.subplot(2,2,4)
sns.boxplot(new_dataFrame['Math_score'])

plt.show()

# %% [markdown]
# Capping

# %%
new_df_cap = dataFrame.copy()

new_df_cap['Math_score'] = np.where(
    new_df_cap['Math_score'] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap['Math_score'] < lower_limit,
        lower_limit,
        new_df_cap['Math_score']
    )
)

# %%
new_df_cap.shape
# Out:
# (400, 5)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(dataFrame['Math_score'])

plt.subplot(2,2,2)
sns.boxplot(dataFrame['Math_score'])

plt.subplot(2,2,3)
sns.distplot(new_df_cap['Math_score'])

plt.subplot(2,2,4)
sns.boxplot(new_df_cap['Math_score'])

plt.show()
